# %%
#MINI PROJECT 1
#CONVERSION OF FILE FORMATS USING PYTHON
# Install Tesseract and other dependencies
# !apt-get update
# !apt-get install -y tesseract-ocr
# !pip install pytesseract pillow gtts
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,626 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Ign:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease
# Get:4 https://r2u.stat.illinois.edu/ubuntu jammy Release [5,713 B]
# Get:5 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:6 https://r2u.stat.illinois.edu/ubuntu jammy Release.gpg [793 B]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [945 kB]
# Get:9 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,560 kB]
# Hit:11 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Get:12 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# ...

# %%
from google.colab import files

# Upload the image file
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d1d78d23-236a-48e0-8098-3a72b4f5ecee" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d1d78d23-236a-48e0-8098-3a72b4f5ecee">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image
import pytesseract
from gtts import gTTS
import os
from IPython.display import display, Audio

def extract_text(image_path):
    # Open the image file
    img = Image.open(image_path)
    # Display the image
    display(img)
    # Use pytesseract to extract text
    text = pytesseract.image_to_string(img)
    return text

def text_to_audio(text, output_audio_path):
    # Convert the text to speech
    tts = gTTS(text=text, lang='en')
    # Save the audio file
    tts.save(output_audio_path)
    print(f'Audio saved as {output_audio_path}')

# Assume the uploaded file is your image
image_path = list(uploaded.keys())[0]
output_audio_path = 'output_audio.mp3'  # Name of the output audio file

# Extract text from the image
text = extract_text(image_path)
print(f'Extracted Text: {text}')

# Convert the extracted text to audio
text_to_audio(text, output_audio_path)

# Play the audio in Colab
Audio(output_audio_path, autoplay=True)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x543>
# Extracted Text: Definition of OCR
#
# OCR (Optical Character Recognition) is a technology that
# converts scanned documents, PDFs, and images into
# machine-readable text.
#
# OCR analyzes an image or document containing printed or
# handwritten characters and then translates it into editable
# electronic text. OCR software can recognize various alphabets,
# numbers, and symbols.
#
# ©
# capacity”
#
# Audio saved as output_audio.mp3
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
